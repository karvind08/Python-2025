# %%
import pickle

# %%
with open('student.dat','wb') as f:
    records = []
    while True:
        r = int(input())
        name = input()
        data = [r,name]
        records.append(data)
        ch = input('Enter')
        if ch  == 'n':
            break
    pickle.dump(records,f)
# Out:
#  1
#  Arvind
# Enter y
#  2
#  Amit
# Enter n

# %%
with open('student.dat','rb') as f:
    try:
        while True:
            res = pickle.load(f)
            for i in res:
                print(i)
    except Exception:
        f.close()
# Out:
# [1, 'arv']
# [2, 'arvndd']

# %%
with open('student.dat','rb') as f:
    try:
        r = int(input('roll Number: '))
        while True:
            res = pickle.load(f)
            if r == res[0]:
                print(r,name)
    except Exception:
        f.close()
# Out:
# roll Number:  2

# %%
with open('student.dat','wb') as f:
    records = []
    while True:
        r = int(input())
        name = input()
        data = [r,name]
        records.append(data)
        ch = input('Enter')
        if ch  == 'n':
            break
    pickle.dump(records,f)
# Out:
#  1
#  arvind
# Enter n

# %%
import pickle
with open('student.dat', 'rb') as f:
    try:
        r = int(input('Enter roll number: '))
        while True:
            res = pickle.load(f)   # res is expected to be a tuple/list like (roll, name, ...)
            if r == res[0]:
                print("Roll Number:", res[0], "Name:", res[1])
                break
    except EOFError:
        print("Record not found.")
# Out:
# Enter roll number:  1
# Record not found.

# %%
f1 = open('Student.dat', 'rb')
rno = int(input('Enter the roll no to search: '))
flag = 0
try:
 while True:
     r = pickle.load(f1)
     if rno == r[0]:
         print (rollno, name, marks)
         flag = 1
except:
 if flag == 0:
 print(“Record not found…”)
f1.close()
# Out:
#   Cell In[21], line 12
#     print(“Record not found…”)
#           ^
# SyntaxError: invalid character '“' (U+201C)

# %%
s1 = input()
res = pickle.dumps(s1)
print(res)
# Out:
#  Hello Python
# b'\x80\x04\x95\x10\x00\x00\x00\x00\x00\x00\x00\x8c\x0cHello Python\x94.'

# %%
re = pickle.loads(b'\x80\x04\x95\x10\x00\x00\x00\x00\x00\x00\x00\x8c\x0cHello Python\x94.')
print(re)
# Out:
# Hello Python
