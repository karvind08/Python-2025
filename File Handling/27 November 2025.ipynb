# %%
import pickle
def writedata():
    with open('db1.dat','wb') as f:
        records = [] 
        while True:
            r = int(input())
            name = input()
            marks = input()
            data = [r,name,marks]
            records.append(data)
            ch = input('Press y and n')
            if ch=='n':
                break
            else:
                pickle.dump(records,f)

writedata()
# Out:
#  1
#  Arvind
#  99
# Press y and n y
#  2
#  Amit
#  98
# Press y and n y
#  3
#  Duggu
#  98
# Press y and n n

# %%
def readdata():
    with open('db1.dat','rb') as f:
        res = pickle.load(f)
        print(res)

readdata()
# Out:
# [[1, 'Arvind', '99']]

# %%
def readdata():
    with open('db1.dat','rb') as f:
        while True:
            res = pickle.load(f)
            for i in res:
                print(i)

readdata()
# Out:
# [1, 'Arvind', '99']
# [1, 'Arvind', '99']
# [2, 'Amit', '98']
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# Cell In[5], line 8
#       5             for i in res:
#       6                 print(i)
# ----> 8 readdata()
#
# Cell In[5], line 4, in readdata()
#       2 with open('db1.dat','rb') as f:
#       3     while True:
# ----> 4         res = pickle.load(f)
#       5         for i in res:
#       6             print(i)
#
# EOFError: Ran out of input

# %%
def readdata():
    try:
        with open('db1.dat','rb') as f:
            while True:
                res = pickle.load(f)
                for i in res:
                    print(i)
    except EOFError:
        f.close()
readdata()
# Out:
# [1, 'Arvind', '99']
# [1, 'Arvind', '99']
# [2, 'Amit', '98']
