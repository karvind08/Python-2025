# %%
# Write a Python program to read an entire text file.

# %%
f = open('data.txt','r')
data = f.read()
print(data)
# Out:
# Write a Python program to read an entire text file.

# %%
# r Mode is by default

# %%
f = open('data.txt')
data = f.read()
print(data)
# Out:
# Write a Python program to read an entire text file.
