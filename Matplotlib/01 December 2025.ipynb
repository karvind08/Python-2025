# %%
from matplotlib import pyplot as plt

# %%
x1 = [2,6,9,13]
y1 = [14,50,67,87]
x2 = [5,19,12,21]
y2 = [21,45,71,89]
plt.bar(x1,y1,color='g',label='First Bar')
plt.bar(x2,y2,color='c',label='Second Bar')
plt.title('Bar Plot')
plt.legend()
plt.xlabel('X-Axis')
plt.xlabel('Y-Axis')
plt.show()

# %%
students = ['A','B','C','D']
marks = [67,78,98,99]
plt.bar(students,marks,color='r',label='First Bar')
plt.title('Bar Plot')
plt.legend()
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %%
students = ['A','B','C','D']
marks = [67,78,98,99]
plt.barh(students,marks,color='r',label='First Bar')
plt.title('Bar Plot')
plt.legend()
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %%
# Pie Plot

# %%
slices = [10,21,30,40,50]
names = ['A','B','C','D','E']
colrs = ['r','g','b','y','c']
plt.pie(slices,
        labels = names,
        colors = colrs,
        startangle = 60,
        shadow = True,
        explode = (0,0,0.1,0,0),
        autopct = '%.2f%%'
       )
plt.show()

# %%
slices = [10,21,30,40,50]
names = ['A','B','C','D','E']
colrs = ['r','g','b','y','c']
plt.pie(slices,
        labels = names,
        colors = colrs,
        shadow = True,
        startangle = 90,
        explode = (0,0,0,0,0.2),
        autopct = '%.2f%%',
       )
plt.show()

# %%
# Histogram Plot

# %%
x = [1,3,4,5,9,12,13,20,25,29,30,36,40]
plt.hist(x,bins=5)
plt.show()

# %%
x = [1,3,4,5,9,12,13,20,25,29,30,36,40]
plt.hist(x,bins=5,edgecolor='r')
plt.title('Histogram Plot')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %%
x = [1,3,4,5,9,12,13,20,25,29,30,36,40]
plt.hist(x,bins=8,edgecolor='r')
plt.title('Histogram Plot')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %%
x = [1,3,4,5,9,12,13,20,25,29,30,36,40]
b = [5,10,15,20,25,30,35,40,50]
plt.hist(x,bins=b,edgecolor='r')
plt.title('Histogram Plot')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %%
x = [1,3,4,5,9,12,13,20,25,29,30,36,40]
b = [5,10,15,20,25,30,35,40,50]
plt.hist(x,bins=b,edgecolor='r',histtype='bar')
plt.title('Histogram Plot')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %%
x = [1,3,4,5,9,12,13,20,25,29,30,36,40]
b = [5,10,15,20,25,30,35,40,50]
plt.hist(x,bins=b,edgecolor='r',histtype='barstacked')
plt.title('Histogram Plot')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %%
x = [1,3,4,5,9,12,13,20,25,29,30,36,40]
b = [5,10,15,20,25,30,35,40,50]
plt.hist(x,bins=b,edgecolor='r',histtype='step')
plt.title('Histogram Plot')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %%
x = [1,3,4,5,9,12,13,20,25,29,30,36,40]
b = [5,10,15,20,25,30,35,40,50]
plt.hist(x,bins=b,edgecolor='r',histtype='stepfilled')
plt.title('Histogram Plot')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %%
x = [1,3,4,5,9,12,13,20,25,29,30,36,40]
b = [5,10,15,20,25,30,35,40,50]
plt.hist(x,bins=b,edgecolor='r',histtype='bar',align='left')
plt.title('Histogram Plot')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()
